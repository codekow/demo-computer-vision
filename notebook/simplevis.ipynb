# %%
import cv2
import utils
import os
display = utils.notebook_init()  # checks
cap = cv2.VideoCapture(0)
filename = "/image.jpg"
inpath = ''.join(os.getcwd()),filename
otpath = ''.join(os.getcwd()),"/runs/detect/exp",filename
infile = ''.join(inpath)
otfile = ''.join(otpath)
print(infile)
print(otfile)

# Capture frame
ret, frame = cap.read()
if ret:
	cv2.imwrite(infile, frame)

cap.release()

img = infile
display.Image(infile)
# Out:
# YOLOv5 🚀 2022-5-20 Python-3.6.8 torch-1.10.1+cu102 CPU
# Setup complete ✅ (8 CPUs, 62.1 GB RAM, 25.0/898.3 GB disk)
# /root/workspace/yolov5/image.jpg
# /root/workspace/yolov5/runs/detect/exp/image.jpg

# %%
# !rm -rf runs/detect
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source $infile
display.Image(otfile)
# Out:
# detect: weights=['yolov5s.pt'], source=/root/workspace/yolov5/image.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# Python 3.7.0 required by YOLOv5, but Python 3.6.8 is currently installed
# YOLOv5 🚀 2022-5-20 Python-3.6.8 torch-1.10.1+cu102 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# image 1/1 /root/workspace/yolov5/image.jpg: 480x640 1 tv, Done. (0.094s)
# Speed: 5.6ms pre-process, 93.7ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
